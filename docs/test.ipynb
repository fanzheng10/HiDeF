# %%
from hidef import *

# %%
P = ['11111111',
     '11111100',
     '00001111',
     '11100000',
     '00110000',
     '00001100',         
     '00000011']
wv = weaver.Weaver()
H = wv.weave(P, cutoff=1.0)
_ = wv.show()
# Out:
# @> initializing the graph...
# @> graph initialized in 0.00s
# @> removing redudant edges...
# @> redundant edges removed in 0.00s
# @> attaching terminal nodes to the graph...
# @> terminal nodes attached in 0.00s
# @> propagate terminal node assignments upward in the hierarchy
# @> terminal nodes propagated in 0.00s
# @> finding secondary edges...
# @> secondary edges found in 0.00s

# %%
H = wv.weave(P, cutoff=1.0)
_ = wv.show()
# Out:
# @> initializing the graph...
# @> graph initialized in 0.00s
# @> removing redudant edges...
# @> redundant edges removed in 0.00s
# @> attaching terminal nodes to the graph...
# @> terminal nodes attached in 0.00s
# @> propagate terminal node assignments upward in the hierarchy
# @> terminal nodes propagated in 0.00s
# @> finding secondary edges...
# @> secondary edges found in 0.00s

# %%
P = ['11111111',
     '11111100',
     '00111110']
wv = weaver.Weaver()
H = wv.weave(P, cutoff=0.75)
_ = wv.show()
# Out:
# @> initializing the graph...
# @> graph initialized in 0.00s
# @> removing redudant edges...
# @> redundant edges removed in 0.00s
# @> attaching terminal nodes to the graph...
# @> terminal nodes attached in 0.00s
# @> propagate terminal node assignments upward in the hierarchy
# @> terminal nodes propagated in 0.00s
# @> finding secondary edges...
# @> secondary edges found in 0.00s

# %%
P = ['11111111',
     '11111100',
     '00111110']
wv = weaver.Weaver()
H = wv.weave(P, cutoff=1.0)
_ = wv.show()
# Out:
# @> initializing the graph...
# @> graph initialized in 0.00s
# @> removing redudant edges...
# @> redundant edges removed in 0.00s
# @> attaching terminal nodes to the graph...
# @> terminal nodes attached in 0.00s
# @> propagate terminal node assignments upward in the hierarchy
# @> terminal nodes propagated in 0.00s
# @> finding secondary edges...
# @> secondary edges found in 0.00s

# %%
P = ['11111110',
     '11111110']
H = wv.weave(P, merge=True)
_ = wv.show()
# Out:
# @> initializing the graph...
# @> graph initialized in 0.00s
# @> "merge" parameter set to true, so merging redundant clusters...
# @> Merge 1 redundant groups ...
# @> redundant nodes removed in 0.00s
# @> removing redudant edges...
# @> redundant edges removed in 0.00s
# @> attaching terminal nodes to the graph...
# @> terminal nodes attached in 0.00s
# @> propagate terminal node assignments upward in the hierarchy
# @> terminal nodes propagated in 0.00s
# @> finding secondary edges...
# @> secondary edges found in 0.00s

# %%
P = ['11111110',
     '11111110']
wv = weaver.Weaver()
H = wv.weave(P, merge=False)
_ = wv.show()
# Out:
# @> initializing the graph...
# @> graph initialized in 0.00s
# @> removing redudant edges...
# @> redundant edges removed in 0.00s
# @> attaching terminal nodes to the graph...
# @> terminal nodes attached in 0.00s
# @> propagate terminal node assignments upward in the hierarchy
# @> terminal nodes propagated in 0.00s
# @> finding secondary edges...
# @> secondary edges found in 0.00s
